# %% [markdown]
# <a href="https://colab.research.google.com/github/juanconcep0770/Inteligencia-Artificial/blob/main/Red_REGRESION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#En este código, se generan datos de entrenamiento X_train y y_train utilizando valores de entrada (X_train) y la función seno (y_train). 
#Luego, se crea un modelo secuencial utilizando la biblioteca Keras y se agregan capas densas con funciones de activación relu y 
#una capa de salida con una función de activación lineal.
#El modelo se compila con una función de pérdida de error cuadrático medio (mse) y el optimizador adam. A continuación, 
#se entrena el modelo utilizando los datos de entrenamiento durante 100 épocas con un tamaño de lote de 32.
#Después de entrenar el modelo, se generan datos de prueba X_test y se utilizan para obtener las predicciones del modelo con la función predict(). 
#Finalmente, se imprimen las predicciones.

import numpy as np
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt

# Generar datos de entrenamiento
X_train = np.linspace(0, 2*np.pi, 1000)  # Valores de entrada
y_train = np.sin(X_train)  # Valores de salida deseados

# Crear el modelo de la red neuronal
model = Sequential()
model.add(Dense(10, input_shape=(1,), activation='relu'))  #capa oculta de 10 neuronas
model.add(Dense(10, activation='relu'))                    #capa oculta de 10 neuronas
model.add(Dense(1, activation='linear'))                   #capa salida de 1 neuronas

# Compilar el modelo
model.compile(loss='mse', optimizer='adam')

# Entrenar el modelo
model.fit(X_train, y_train, epochs=100, batch_size=50)

# Generar datos de prueba
X_test = np.linspace(0, 2*np.pi, 100)  # Valores de entrada para prueba

# Obtener las predicciones del modelo
#y_pred = model.predict(X_test)

# Imprimir las predicciones
#print(y_pred)

# Graficar la función a predecir
plt.figure(figsize=(8, 6))
plt.scatter(X_train, y_train, color='blue', label='Función a predecir')
plt.plot(X_test, y_pred, color='red', label='Predicción')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Aproximación de la función seno')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 20/20 [==============================] - 1s 2ms/step - loss: 1.6157
# Epoch 2/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.1302
# Epoch 3/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.8554
# Epoch 4/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6961
# Epoch 5/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5694
# Epoch 6/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4752
# Epoch 7/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3962
# Epoch 8/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3530
# Epoch 9/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3212
# Epoch 10/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2923
# Epoch 11/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2656
# Epoch 12/100
# ...
